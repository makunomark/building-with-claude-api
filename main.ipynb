# %%
print("hello world!")
# Out:
# hello world!

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
message = client.messages.create(
  model=model,
  max_tokens=1024,
  messages=[
    {"role": "user", "content": "What is quantam computing? Answer in one sentence."}
  ]
)

# %%
message.content[0].text
# Out:
# 'Quantum computing is a revolutionary computing paradigm that uses quantum mechanical phenomena like superposition and entanglement to process information in quantum bits (qubits), potentially solving certain complex problems exponentially faster than classical computers.'
