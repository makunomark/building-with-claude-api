# %%
print("hello world!")
# Out:
# hello world!

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
message = client.messages.create(
  model=model,
  max_tokens=1024,
  messages=[
    {"role": "user", "content": "What is quantum computing? Answer in one sentence."}
  ]
)
message = client.messages.create(
  model=model,
  max_tokens=1024,
  messages=[
    {"role": "user", "content": "Write another sentence."}
  ]
)
message.content[0].text
# Out:
# 'The morning sunlight filtered through the maple leaves, casting dancing shadows on the garden path.'

# %%
def add_user_message(messages, text):
  user_message = {"role": "user", "content": text}
  messages.append(user_message)

def add_assistant_message(messages, text):
  assistant_message = {"role": "assistant", "content": text}
  messages.append(assistant_message)

def chat(messages):
  message = client.messages.create(
    model=model,
    max_tokens=1024,
    messages=messages
  )
  return message.content[0].text

# %%
messages = []
add_user_message(messages, "What is quantum computing? Answer in one sentence.")
answer = chat(messages)
add_assistant_message(messages, answer)
add_user_message(messages, "Write another sentence.")
print("Messages so far:", messages)
answer = chat(messages)
answer
# Out:
# Messages so far: [{'role': 'user', 'content': 'What is quantum computing? Answer in one sentence.'}, {'role': 'assistant', 'content': 'Quantum computing is a type of computation that uses quantum mechanical phenomena like superposition and entanglement to process information in ways that can potentially solve certain problems exponentially faster than classical computers.'}, {'role': 'user', 'content': 'Write another sentence.'}]
# 'Quantum computers leverage quantum bits (qubits) that can exist in multiple states simultaneously, unlike classical bits that are either 0 or 1, enabling them to perform many calculations in parallel.'

# %%
messages = []

while True:
  user_input = input("> ")
  print(">", user_input)
  add_user_message(messages, user_input)
  answer = chat(messages)
  add_assistant_message(messages, answer)
  print("------------")
  print(answer)
  print("------------")
# Out:
# > What is 1 + 1
# ------------
# 1 + 1 = 2
# ------------
# > Add 15 to your answer
# ------------
# 2 + 15 = 17
# ------------
# > What is your name, include your last answer and feel free to be creative
# ------------
# My name is Claude, and just like that last answer of 17, I'm here to help you calculate, create, and explore ideas together!
# ------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 4
#       1 messages = []
#       3 while True:
# ----> 4   user_input = input("> ")
#       5   print(">", user_input)
#       6   add_user_message(messages, user_input)
#
# File ~/dev/building-with-claude-api/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~/dev/building-with-claude-api/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
